# %% [markdown]
# # Histogramme

# %% [markdown]
# Befehl rnorm(n = 200, mean = 100, sd = 15): Wählt zufällig
# 200 normalverteilte Daten (siehe Kapitel Normalverteilung) mit
# Mittelwert 100 mit Standardabweichung 15 aus
#
# Befehl hist(iq, ...): Histogramm für die Daten iq
#
# * xlab steht für x -Label, die Beschriftung der x -Achse
# * ylab steht für y -Label, die Beschriftung der y -Achse
# * col steht für color
# * main steht für Haupttitel
# * freq wenn F wird Histogram normiert gezeichnet

# %%
iq <- rnorm(n = 200, mean = 100, sd = 15)
hist(iq,
     freq = T,
    col = "darkseagreen3",
    xlab = "Punkte im IQ-Test",
    ylab = "Anzahl Personen",
    main = "Verteilung der Punkte in einem IQ-Test"
)
# Out:
# Plot with title "Verteilung der Punkte in einem IQ-Test"

# %% [markdown]
# ## breaks
# Mit "breaks" gibt man an, wie viele "Säulen" das Histogram zeichnet. Es ist allerdings nur ein Vorschlag, siehe letztes Histogram wo breaks = 3, aber R zeichnet 4.

# %%
par(mfrow = c(2, 2)) # histogramme in 2 reihen und 2 zeilen anordnen
hist(iq,
breaks = 100,
xlab = "100 Klassen",
ylab = "Häufigkeit",
col = "darkseagreen3"
)
hist(iq,
breaks = 20,
xlab = "20 Klassen",
ylab = "Häufigkeit",
col = "darkseagreen3"
)
hist(iq,
breaks = "sturges", # default R
xlab = "Sturges-Regel von R",
ylab = "Häufigkeit",
col = "darkseagreen3"
)
hist(iq,
breaks = 3,
xlab = "4 Klassen",
ylab = "Häufigkeit",
col = "darkseagreen3"
)
# Out:
# Plot with title "Histogram of iq"
